# %% [markdown]
# # Enhancing Health Equity: A data-driven approach for Health Facility Placement in Rwanda
#
# This notebook aims to predict healthcare accessibility score in Rwanda based on population density, number of facilities in the area, road networks and average time to reach said facilities.

# %%
# !pip install pandas numpy scikit-learn torch matplotlib seaborn requests geopandas rasterio gdal fiona shapely
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [12 lines of output]
#       Using numpy 2.3.4
#       /tmp/pip-build-env-n8pjclhb/overlay/lib/python3.12/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsWarning: `license` overwritten by `pyproject.toml`
#         corresp(dist, value, root_dir)
#       /tmp/pip-build-env-n8pjclhb/overlay/lib/python3.12/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsWarning: `extras_require` overwritten in `pyproject.toml` (optional-dependencies)
#         corresp(dist, value, root_dir)
#       running egg_info
#       writing gdal-utils/GDAL.egg-info/PKG-INFO
#       writing dependency_links to gdal-utils/GDAL.egg-info/dependency_links.txt
#       writing entry points to gdal-utils/GDAL.egg-info/entry_points.txt
# ...

# %%
# Import libraries
import pandas as pd
import numpy as np
import requests
import geopandas as gpd
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import joblib
from pathlib import Path

# %%
# Load population
url =
